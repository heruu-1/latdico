# %% [markdown]
# <a href="https://colab.research.google.com/github/heruu-1/latdico/blob/main/latihan_wrangling%2CEDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #Gathering

# %%
customer_df=pd.read_csv('https://raw.githubusercontent.com/dicodingacademy/dicoding_dataset/refs/heads/main/DicodingCollection/customers.csv')
customer_df.head()
# Out:
#    customer_id customer_name             gender  age  \
# 0            1       fulan 1             Female   30
# 1            2       fulan 2  Prefer not to say   69
# 2            3       fulan 3  Prefer not to say   59
# 3            4       fulan 4  Prefer not to say   67
# 4            5       fulan 5  Prefer not to say   30
#
#                      home_address  zip_code               city  \
# 0  8606 Victoria TerraceSuite 560      5464      Johnstonhaven
# 1      8327 Kirlin SummitApt. 461      8223    New Zacharyfort
# 2       269 Gemma SummitSuite 109      5661           Aliburgh
# 3       743 Bailey GroveSuite 141      1729  South Justinhaven
# 4         48 Hyatt ManorSuite 375      4032     Griffithsshire
#
#                           state    country
# 0            Northern Territory  Australia
# 1               South Australia  Australia
# 2  Australian Capital Territory  Australia
# 3                    Queensland  Australia
# 4                    Queensland  Australia

# %%
order_df=pd.read_csv('https://raw.githubusercontent.com/dicodingacademy/dicoding_dataset/refs/heads/main/DicodingCollection/orders.csv')
order_df.head()
# Out:
#    order_id  customer_id  payment order_date delivery_date
# 0         1           64    30811  2021-8-30    2021-09-24
# 1         2          473    50490   2021-2-3    2021-02-13
# 2         3          774    46763  2021-10-8    2021-11-03
# 3         4          433    39782   2021-5-6    2021-05-19
# 4         5          441    14719  2021-3-23    2021-03-24

# %%
product_df=pd.read_csv('https://raw.githubusercontent.com/dicodingacademy/dicoding_dataset/refs/heads/main/DicodingCollection/products.csv')
product_df.head()
# Out:
#    product_id product_type  product_name size colour  price  quantity  \
# 0           0        Shirt  Oxford Cloth   XS    red    114        66
# 1           1        Shirt  Oxford Cloth    S    red    114        53
# 2           2        Shirt  Oxford Cloth    M    red    114        54
# 3           3        Shirt  Oxford Cloth    L    red    114        69
# 4           4        Shirt  Oxford Cloth   XL    red    114        47
#
#                                     description
# 0  A red coloured, XS sized, Oxford Cloth Shirt
# 1   A red coloured, S sized, Oxford Cloth Shirt
# 2   A red coloured, M sized, Oxford Cloth Shirt
# 3   A red coloured, L sized, Oxford Cloth Shirt
# 4  A red coloured, XL sized, Oxford Cloth Shirt

# %%
sales_df=pd.read_csv('https://raw.githubusercontent.com/dicodingacademy/dicoding_dataset/refs/heads/main/DicodingCollection/sales.csv')
sales_df.head()
# Out:
#    sales_id  order_id  product_id  price_per_unit  quantity  total_price
# 0         0         1         218             106         2        212.0
# 1         1         1         481             118         1        118.0
# 2         2         1           2              96         3        288.0
# 3         3         1        1002             106         2        212.0
# 4         4         1         691             113         3        339.0

# %% [markdown]
# #Assesing data

# %%
customer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1007 entries, 0 to 1006
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customer_id    1007 non-null   int64
#  1   customer_name  1007 non-null   object
#  2   gender         989 non-null    object
#  3   age            1007 non-null   int64
#  4   home_address   1007 non-null   object
#  5   zip_code       1007 non-null   int64
#  6   city           1007 non-null   object
#  7   state          1007 non-null   object
#  8   country        1007 non-null   object
# dtypes: int64(3), object(6)
# memory usage: 70.9+ KB

# %%
customer_df.isnull().sum()
# Out:
# customer_id       0
# customer_name     0
# gender           18
# age               0
# home_address      0
# zip_code          0
# city              0
# state             0
# country           0
# dtype: int64

# %%
print('Jumlah duplikasi: ', customer_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  6

# %%
customer_df.describe()
# Out:
#        customer_id          age     zip_code
# count  1007.000000  1007.000000  1007.000000
# mean    501.726912    50.929494  5012.538232
# std     288.673238    30.516299  2885.836112
# min       1.000000    20.000000     2.000000
# 25%     252.500000    34.000000  2403.500000
# 50%     502.000000    50.000000  5087.000000
# 75%     751.500000    65.000000  7493.500000
# max    1000.000000   700.000000  9998.000000

# %%
order_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       1000 non-null   int64
#  1   customer_id    1000 non-null   int64
#  2   payment        1000 non-null   int64
#  3   order_date     1000 non-null   object
#  4   delivery_date  1000 non-null   object
# dtypes: int64(3), object(2)
# memory usage: 39.2+ KB

# %%
print('Jumlah duplikasi: ', order_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
order_df.describe()
# Out:
#           order_id  customer_id       payment
# count  1000.000000  1000.000000   1000.000000
# mean    500.500000   506.640000  33972.936000
# std     288.819436   277.115502  14451.609047
# min       1.000000     1.000000  10043.000000
# 25%     250.750000   275.250000  21329.250000
# 50%     500.500000   515.000000  33697.500000
# 75%     750.250000   737.250000  46249.000000
# max    1000.000000  1000.000000  59910.000000

# %%
product_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1266 entries, 0 to 1265
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product_id    1266 non-null   int64
#  1   product_type  1266 non-null   object
#  2   product_name  1266 non-null   object
#  3   size          1266 non-null   object
#  4   colour        1266 non-null   object
#  5   price         1266 non-null   int64
#  6   quantity      1266 non-null   int64
#  7   description   1266 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 79.2+ KB

# %%
print('Jumlah duplikasi: ', product_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  6

# %%
product_df.describe()
# Out:
#         product_id        price     quantity
# count  1266.000000  1266.000000  1266.000000
# mean    627.926540   105.812006    60.138231
# std     363.971586     9.715611    11.682791
# min       0.000000    90.000000    40.000000
# 25%     313.250000    95.250000    50.000000
# 50%     626.500000   109.000000    60.000000
# 75%     942.750000   114.000000    70.000000
# max    1259.000000   119.000000    80.000000

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sales_id        5000 non-null   int64
#  1   order_id        5000 non-null   int64
#  2   product_id      5000 non-null   int64
#  3   price_per_unit  5000 non-null   int64
#  4   quantity        5000 non-null   int64
#  5   total_price     4981 non-null   float64
# dtypes: float64(1), int64(5)
# memory usage: 234.5 KB

# %%
sales_df.isnull().sum()
# Out:
# sales_id           0
# order_id           0
# product_id         0
# price_per_unit     0
# quantity           0
# total_price       19
# dtype: int64

# %%
print('Jumlah duplikasi: ', sales_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
sales_df.describe()
# Out:
#           sales_id     order_id   product_id  price_per_unit    quantity  \
# count  5000.000000  5000.000000  5000.000000     5000.000000  5000.00000
# mean   2499.500000   503.038200   634.053200      103.501600     1.99240
# std    1443.520003   285.964418   363.255794        9.195004     0.80751
# min       0.000000     1.000000     1.000000       90.000000     1.00000
# 25%    1249.750000   258.000000   323.000000       95.000000     1.00000
# 50%    2499.500000   504.500000   635.000000      102.000000     2.00000
# 75%    3749.250000   749.000000   951.000000      112.000000     3.00000
# max    4999.000000   999.000000  1259.000000      119.000000     3.00000
#
#        total_price
# count  4981.000000
# mean    206.307368
# std      86.352449
# min      90.000000
# 25%     112.000000
# 50%     204.000000
# 75%     285.000000
# max     357.000000

# %% [markdown]
# #Cleaning

# %%
customer_df.drop_duplicates(inplace=True)
order_df.drop_duplicates(inplace=True)
product_df.drop_duplicates(inplace=True)
sales_df.drop_duplicates(inplace=True)

# %%
customer_df[customer_df.gender.isnull()]
# Out:
#      customer_id customer_name gender  age                     home_address  \
# 38            39      fulan 39    NaN   80  7440 Cameron Estate DrSuite 628
# 167          168     fulan 168    NaN   27         2781 Berge MallSuite 452
# 322          322     fulan 322    NaN   30        593 Becker CircleApt. 333
# 393          393     fulan 393    NaN   34          5158 Levi HillSuite 531
# 442          442     fulan 442    NaN   26           5157 Feil RoadApt. 633
# 722          720     fulan 720    NaN   40         31 Jordan ParadeApt. 400
# 745          743     fulan 743    NaN   57   09 Christopher StreetSuite 967
# 773          771     fulan 771    NaN   74     7367 Wright JunctionApt. 773
# 798          795     fulan 795    NaN   49          487 Summer MewsApt. 874
# 801          798     fulan 798    NaN   56           27 Aiden KnollApt. 875
# 825          822     fulan 822    NaN   59        41 Jenkins KnollSuite 438
# ...

# %%
customer_df.gender.value_counts()
# Out:
# gender
# Prefer not to say    725
# Male                 143
# Female               115
# Name: count, dtype: int64

# %%
customer_df.fillna(value='Prefer not to say',inplace=True)
customer_df.isnull().sum()
# Out:
# customer_id      0
# customer_name    0
# gender           0
# age              0
# home_address     0
# zip_code         0
# city             0
# state            0
# country          0
# dtype: int64

# %%
customer_df.gender.value_counts()
# Out:
# gender
# Prefer not to say    743
# Male                 143
# Female               115
# Name: count, dtype: int64

# %%
customer_df[customer_df.age == customer_df.age.max()]
# Out:
#      customer_id customer_name             gender  age  \
# 967          961     fulan 961  Prefer not to say  700
#
#                    home_address  zip_code        city            state  \
# 967  29 Farrell ParadeSuite 818      6528  New Joseph  South Australia
#
#        country
# 967  Australia

# %%
customer_df.age.replace(customer_df.age.max(),70,inplace=True)

# %%
customer_df[customer_df.age == customer_df.age.max()]
# Out:
#      customer_id customer_name             gender  age  \
# 215          216     fulan 216  Prefer not to say  500
#
#                home_address  zip_code       city               state  \
# 215  038 Haley MewsApt. 810      3991  Bayertown  Northern Territory
#
#        country
# 215  Australia

# %%
customer_df.age.replace(customer_df.age.max(),50,inplace=True)

# %%
customer_df[customer_df.age == customer_df.age.max()]
# Out:
#      customer_id customer_name             gender  age  \
# 34            35      fulan 35               Male   80
# 38            39      fulan 39  Prefer not to say   80
# 142          143     fulan 143  Prefer not to say   80
# 154          155     fulan 155               Male   80
# 170          171     fulan 171  Prefer not to say   80
# 174          175     fulan 175  Prefer not to say   80
# 181          182     fulan 182               Male   80
# 235          236     fulan 236  Prefer not to say   80
# 424          424     fulan 424  Prefer not to say   80
# 438          438     fulan 438  Prefer not to say   80
# 495          495     fulan 495               Male   80
# 524          524     fulan 524  Prefer not to say   80
# 598          597     fulan 597  Prefer not to say   80
# 703          702     fulan 702  Prefer not to say   80
# 734          732     fulan 732  Prefer not to say   80
#
#                           home_address  zip_code                   city  \
# ...

# %%
customer_df.describe()
# Out:
#        customer_id          age     zip_code
# count  1001.000000  1001.000000  1001.000000
# mean    500.942058    49.874126  5000.693307
# std     289.013599    17.644663  2886.084454
# min       1.000000    20.000000     2.000000
# 25%     251.000000    34.000000  2398.000000
# 50%     501.000000    50.000000  5079.000000
# 75%     751.000000    65.000000  7454.000000
# max    1000.000000    80.000000  9998.000000

# %%
datetime_columns = ['order_date', 'delivery_date']
for column in datetime_columns:
  order_df[column] = pd.to_datetime(order_df[column])

# %%
order_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       1000 non-null   int64
#  1   customer_id    1000 non-null   int64
#  2   payment        1000 non-null   int64
#  3   order_date     1000 non-null   datetime64[ns]
#  4   delivery_date  1000 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), int64(3)
# memory usage: 39.2 KB

# %%
product_df.drop_duplicates(inplace=True)

# %%
print('Jumlah duplikasi: ', product_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
sales_df[sales_df.total_price.isnull()]
# Out:
#       sales_id  order_id  product_id  price_per_unit  quantity  total_price
# 9            9         2        1196             105         1          NaN
# 121        121        27        1027              90         3          NaN
# 278        278        63         360              94         2          NaN
# 421        421        95        1091             115         1          NaN
# 489        489       108        1193             105         3          NaN
# 539        539       117         405             119         2          NaN
# 636        636       134         653              93         3          NaN
# 687        687       145        1138             102         1          NaN
# 854        854       177          64             104         1          NaN
# 1079      1079       222         908              94         3          NaN
# 1193      1193       248        1121             102         2          NaN
# ...

# %%
sales_df['total_price']=sales_df['price_per_unit']*sales_df['quantity']

# %%
sales_df.isnull().sum()
# Out:
# sales_id          0
# order_id          0
# product_id        0
# price_per_unit    0
# quantity          0
# total_price       0
# dtype: int64

# %% [markdown]
# #EDA

# %%
customer_df.describe(include='all')
# Out:
#         customer_id customer_name             gender          age  \
# count   1001.000000          1001               1001  1001.000000
# unique          NaN          1000                  3          NaN
# top             NaN     fulan 943  Prefer not to say          NaN
# freq            NaN             2                743          NaN
# mean     500.942058           NaN                NaN    49.874126
# std      289.013599           NaN                NaN    17.644663
# min        1.000000           NaN                NaN    20.000000
# 25%      251.000000           NaN                NaN    34.000000
# 50%      501.000000           NaN                NaN    50.000000
# 75%      751.000000           NaN                NaN    65.000000
# max     1000.000000           NaN                NaN    80.000000
#
#                       home_address     zip_code     city            state  \
# count                         1001  1001.000000     1001             1001
# ...

# %%
customer_df.groupby(by='gender').agg({
    'customer_id': 'nunique',
    'age': ['mean','max','min','std']
})
# Out:
#                   customer_id        age
#                       nunique       mean max min        std
# gender
# Female                    115  49.147826  79  20  16.646607
# Male                      143  51.230769  80  20  18.462635
# Prefer not to say         742  49.725437  80  20  17.644283

# %%
customer_df.groupby(by='city').customer_id.nunique().sort_values(ascending=False)
# Out:
# city
# East Aidan       3
# East Sophia      3
# New Ava          3
# West Jackfort    2
# Corkeryshire     2
#                 ..
# Jordanside       1
# Josephland       1
# Josephmouth      1
# Justinport       1
# Zacville         1
# Name: customer_id, Length: 961, dtype: int64

# %%
customer_df.groupby(by='state').customer_id.nunique().sort_values(ascending=False)
# Out:
# state
# South Australia                 139
# Queensland                      134
# New South Wales                 132
# Northern Territory              125
# Western Australia               124
# Australian Capital Territory    121
# Victoria                        121
# Tasmania                        104
# Name: customer_id, dtype: int64

# %%
delivery_time=order_df['delivery_date']-order_df['order_date']
delivery_time=delivery_time.apply(lambda x: x.total_seconds())
order_df['delivery_time']=round(delivery_time/86400)
order_df.head(1)
# Out:
#    order_id  customer_id  payment order_date delivery_date  delivery_time
# 0         1           64    30811 2021-08-30    2021-09-24           25.0

# %%
order_df.describe(include='all')
# Out:
#           order_id  customer_id       payment                  order_date  \
# count  1000.000000  1000.000000   1000.000000                        1000
# mean    500.500000   506.640000  33972.936000  2021-05-27 18:38:52.800000
# min       1.000000     1.000000  10043.000000         2021-01-01 00:00:00
# 25%     250.750000   275.250000  21329.250000         2021-03-13 18:00:00
# 50%     500.500000   515.000000  33697.500000         2021-05-27 12:00:00
# 75%     750.250000   737.250000  46249.000000         2021-08-12 06:00:00
# max    1000.000000  1000.000000  59910.000000         2021-10-24 00:00:00
# std     288.819436   277.115502  14451.609047                         NaN
#
#              delivery_date  delivery_time
# count                 1000    1000.000000
# mean   2021-06-10 20:31:12      14.078000
# min    2021-01-03 00:00:00       1.000000
# 25%    2021-03-28 00:00:00       8.000000
# 50%    2021-06-11 12:00:00      14.000000
# 75%    2021-08-24 06:00:00      21.000000
# ...

# %%
customer_order=order_df.customer_id.tolist()
customer_df['Status']=customer_df['customer_id'].apply(lambda x:"active" if x in customer_order else "not active")
customer_df.sample(2)
# Out:
#      customer_id customer_name             gender  age  \
# 177          178     fulan 178  Prefer not to say   51
# 792          789     fulan 789  Prefer not to say   36
#
#                  home_address  zip_code       city  \
# 177  7504 Phoebe RoadApt. 552      6282   Lewiston
# 792  638 Thomas ManorApt. 038      1438  Aliceland
#
#                             state    country  Status
# 177  Australian Capital Territory  Australia  active
# 792             Western Australia  Australia  active

# %%
customer_df.groupby(by='Status').customer_id.count()
# Out:
# Status
# active        617
# not active    384
# Name: customer_id, dtype: int64

# %%
order_customer=pd.merge(
    left=order_df,
    right=customer_df,
    how='left',
    left_on='customer_id',
    right_on='customer_id'
)
order_customer.sample(5)
# Out:
#      order_id  customer_id  payment order_date delivery_date  delivery_time  \
# 467       468          238    56092 2021-04-15    2021-04-17            2.0
# 258       259          878    47527 2021-08-16    2021-09-07           22.0
# 819       820          801    33182 2021-09-25    2021-10-03            8.0
# 106       107          127    58760 2021-01-11    2021-02-03           23.0
# 628       629          904    36276 2021-08-07    2021-08-20           13.0
#
#     customer_name             gender  age                  home_address  \
# 467     fulan 238  Prefer not to say   30  4435 O'hara TerraceSuite 232
# 258     fulan 878  Prefer not to say   54          478 Amy RunSuite 042
# 819     fulan 801             Female   64      843 Goodwin MewsApt. 699
# 106     fulan 127  Prefer not to say   30      769 Gibson TrailApt. 359
# 628     fulan 904  Prefer not to say   48     9585 Bogan PlazaSuite 155
#
# ...

# %%
order_customer.groupby(by='city').order_id.count().sort_values(ascending=False).reset_index().head(5)
# Out:
#          city  order_id
# 0  Jordanside         6
# 1     New Ava         6
# 2   Lake Rose         5
# 3  O'keefeton         5
# 4    East Max         5

# %%
order_customer.groupby(by='state').order_id.count().sort_values(ascending=False).reset_index().head(5)
# Out:
#                           state  order_id
# 0               South Australia       148
# 1                    Queensland       139
# 2             Western Australia       130
# 3               New South Wales       129
# 4  Australian Capital Territory       118

# %%
order_customer.groupby(by='gender').order_id.count().sort_values(ascending=False).reset_index()
# Out:
#               gender  order_id
# 0  Prefer not to say       725
# 1             Female       139
# 2               Male       136

# %%
order_customer['age_group']=order_customer.age.apply(lambda x: 'youth' if x<=24 else ('senior' if x >64 else 'adult'))

# %%
order_customer.groupby(by='age_group').order_id.count().sort_values(ascending=False).reset_index()
# Out:
#   age_group  order_id
# 0     adult       681
# 1    senior       226
# 2     youth        93

# %%
product_df.describe(include='all')
# Out:
#          product_id product_type product_name  size colour        price  \
# count   1260.000000         1260         1260  1260   1260  1260.000000
# unique          NaN            3           35     8      7          NaN
# top             NaN        Shirt        Denim    XS    red          NaN
# freq            NaN          420           70   252    180          NaN
# mean     629.500000          NaN          NaN   NaN    NaN   105.805556
# std      363.874979          NaN          NaN   NaN    NaN     9.704423
# min        0.000000          NaN          NaN   NaN    NaN    90.000000
# 25%      314.750000          NaN          NaN   NaN    NaN    95.750000
# 50%      629.500000          NaN          NaN   NaN    NaN   108.500000
# 75%      944.250000          NaN          NaN   NaN    NaN   114.000000
# max     1259.000000          NaN          NaN   NaN    NaN   119.000000
#
#            quantity                                   description
# ...

# %%
sales_df.describe(include='all')
# Out:
#           sales_id     order_id   product_id  price_per_unit    quantity  \
# count  5000.000000  5000.000000  5000.000000     5000.000000  5000.00000
# mean   2499.500000   503.038200   634.053200      103.501600     1.99240
# std    1443.520003   285.964418   363.255794        9.195004     0.80751
# min       0.000000     1.000000     1.000000       90.000000     1.00000
# 25%    1249.750000   258.000000   323.000000       95.000000     1.00000
# 50%    2499.500000   504.500000   635.000000      102.000000     2.00000
# 75%    3749.250000   749.000000   951.000000      112.000000     3.00000
# max    4999.000000   999.000000  1259.000000      119.000000     3.00000
#
#        total_price
# count  5000.000000
# mean    206.360000
# std      86.357457
# min      90.000000
# 25%     112.000000
# 50%     204.000000
# 75%     285.000000
# max     357.000000

# %%
product_df.sort_values(by='price',ascending=False)
# Out:
#       product_id product_type product_name size  colour  price  quantity  \
# 704          698       Jacket        Parka    L  violet    119        53
# 671          665       Jacket        Parka   XS     red    119        65
# 698          692       Jacket        Parka    M  indigo    119        66
# 699          693       Jacket        Parka    L  indigo    119        44
# 700          694       Jacket        Parka   XL  indigo    119        78
# ...          ...          ...          ...  ...     ...    ...       ...
# 1225        1219     Trousers      Pleated   XL  indigo     90        45
# 1226        1220     Trousers      Pleated   XS  violet     90        58
# 1227        1221     Trousers      Pleated    S  violet     90        50
# 1228        1222     Trousers      Pleated    M  violet     90        45
# 599          593       Jacket       Bomber    L  violet     90        68
#
#                                         description
# ...

# %%
product_df.groupby(by='product_type').agg({
    'product_id': 'nunique',
    'quantity': 'sum',
    'price': ['max','min']
})
# Out:
#              product_id quantity price
#                 nunique      sum   max min
# product_type
# Jacket              420    25387   119  90
# Shirt               420    25263   119  92
# Trousers            420    25139   119  90

# %%
product_df.groupby(by='product_name').agg({
    'product_id': 'nunique',
    'quantity': 'sum',
    'price': ['max','min']
})
# Out:
#                   product_id quantity price
#                      nunique      sum   max  min
# product_name
# Bomber                    35     2083    90   90
# Camp Collared             35     2071   112  112
# Cardigan                  35     2032   118  118
# Cargo Pants               35     2146   106  106
# Casual Slim Fit           35     2086   113  113
# Chambray                  35     2020   105  105
# Chinos                    35     2101   100  100
# Coach                     35     2158   115  115
# Cords                     35     2260   113  113
# Cropped                   35     2085    99   99
# Cuban Collar              35     2017    93   93
# Denim                     70     4204   115   92
# Drawstring                35     2042   104  104
# Dress                     35     2125   119  119
# Flannel                   35     2135    96   96
# Henley                    35     2051    92   92
# High-Waisted              35     2198    98   98
# ...

# %%
sales_product=pd.merge(
    left=sales_df,
    right=product_df,
    how='left',
    left_on='product_id',
    right_on='product_id'
)
sales_product.sample(5)
# Out:
#       sales_id  order_id  product_id  price_per_unit  quantity_x  total_price  \
# 3233      3233       651         640              93           1           93
# 296        296        67        1038              90           2          180
# 1826      1826       370         663              93           2          186
# 4539      4539       904         150              91           2          182
# 1688      1688       345         428             107           1          107
#
#      product_type product_name size  colour  price  quantity_y  \
# 3233       Jacket        Coach   XS  yellow    115          52
# 296      Trousers  Relaxed Leg    L    blue     95          61
# 1826       Jacket        Coach    L  violet    115          80
# 4539        Shirt        Linen   XS  yellow    116          55
# 1688       Jacket        Denim    L  orange     92          73
#
#                                          description
# 3233       A yellow coloured, XS sized, Coach Jacket
# ...

# %%
sales_product.groupby(by='product_type').agg({
    'product_id': 'nunique',
    'quantity_x': 'sum',
    'total_price': 'sum'
})
# Out:
#               product_id  quantity_x  total_price
# product_type
# Jacket               405        3343       357026
# Shirt                416        3259       333600
# Trousers             412        3360       341174

# %%
sales_product.groupby(by='product_name').agg({
    'product_id': 'nunique',
    'quantity_x': 'sum',
    'total_price': 'sum'
}).sort_values(by='total_price',ascending=False)
# Out:
#                    product_id  quantity_x  total_price
# product_name
# Denim                      67         527        52399
# Casual Slim Fit            35         306        36414
# Trench Coat                33         299        35581
# Shearling                  34         302        35334
# Puffer                     34         298        35164
# Flannel                    34         281        33158
# Cropped                    35         284        32660
# Pleated                    35         308        32340
# Joggers                    34         334        31062
# Chambray                   34         290        30740
# Parka                      35         269        30397
# Bomber                     35         297        29700
# Chinos                     34         260        29380
# Windbreaker                35         287        29274
# Cardigan                   34         260        29120
# Peacoat                    31         266        28994
# ...

# %%
all_df=pd.merge(
    left=sales_product,
    right=order_customer,
    how='left',
    left_on='order_id',
    right_on='order_id'
)
all_df.sample(5)
# Out:
#       sales_id  order_id  product_id  price_per_unit  quantity_x  total_price  \
# 1007      1007       206         553              98           3          294
# 3803      3803       759         266              95           2          190
# 1317      1317       273         522             102           1          102
# 1276      1276       264        1024              90           2          180
# 2731      2731       545         977              97           3          291
#
#      product_type product_name size  colour  ...  customer_name  \
# 1007       Jacket      Leather    L  indigo  ...      fulan 654
# 3803        Shirt         Polo    S    blue  ...      fulan 857
# 1317       Jacket  Windbreaker    M  violet  ...      fulan 828
# 1276     Trousers  Relaxed Leg   XL  orange  ...      fulan 636
# 2731     Trousers     Slim-Fit    M  violet  ...      fulan 439
#
#                  gender age                    home_address  zip_code  \
# ...

# %%
all_df.groupby(by=['state','product_type']).agg({
    'quantity_x': 'sum',
    'total_price': 'sum'
}).sort_values(by='total_price',ascending=True)
# Out:
#                                            quantity_x  total_price
# state                        product_type
# Northern Territory           Shirt                336        33865
# Tasmania                     Trousers             379        38057
# Victoria                     Jacket               359        38203
# Northern Territory           Jacket               365        38991
#                              Trousers             384        38998
# Tasmania                     Shirt                387        39668
# New South Wales              Trousers             392        39766
# Victoria                     Shirt                390        40206
# Western Australia            Shirt                393        40242
# Australian Capital Territory Shirt                396        40448
# Western Australia            Jacket               390        41659
# Victoria                     Trousers             414        41948
# ...

# %%
all_df.groupby(by=['gender','product_type']).agg({
    'quantity_x': 'sum',
    'total_price': 'sum'
}).sort_values(by='total_price',ascending=True)
# Out:
#                                 quantity_x  total_price
# gender            product_type
# Male              Shirt                410        41939
# Female            Shirt                445        45146
# Male              Trousers             453        46071
# Female            Trousers             481        49295
#                   Jacket               481        50963
# Male              Jacket               480        50978
# Prefer not to say Trousers            2426       245808
#                   Shirt               2404       246515
#                   Jacket              2382       255085

# %%
all_df.groupby(by=['age_group','product_type']).agg({
    'quantity_x': 'sum',
    'total_price': 'sum'
}).sort_values(by='total_price',ascending=True)
# Out:
#                         quantity_x  total_price
# age_group product_type
# youth     Jacket               274        29012
#           Shirt                301        30842
#           Trousers             322        32432
# senior    Shirt                733        74977
#           Trousers             766        77471
#           Jacket               777        82959
# adult     Shirt               2225       227781
#           Trousers            2272       231271
#           Jacket              2292       245055

# %% [markdown]
# #Data Visualization

# %%
monthly_order=all_df.resample(rule='M',on='order_date').agg({
    'order_id': 'nunique',
    'total_price': 'sum'
})
monthly_order.index=monthly_order.index.strftime('%Y-%m')
monthly_order=monthly_order.reset_index()
monthly_order.rename(columns={
    'order_id': 'order_count',
    'total_price': 'revenue'
},inplace=True)
monthly_order.head()
# Out:
#   order_date  order_count  revenue
# 0    2021-01          109   119333
# 1    2021-02           93    95080
# 2    2021-03          117   131364
# 3    2021-04           99    97530
# 4    2021-05           84    85597

# %%
monthly_order = all_df.resample(rule='M', on='order_date').agg({
    "order_id": "nunique",
    "total_price": "sum"
})
monthly_order.index = monthly_order.index.strftime('%B')
monthly_order = monthly_order.reset_index()
monthly_order.rename(columns={
    "order_id": "order_count",
    "total_price": "revenue"
}, inplace=True)

plt.figure(figsize=(12,6))
plt.plot(monthly_order.order_date,monthly_order.order_count,marker='o',linewidth=2,color='blue')
plt.title('Number of order per month (2021)',fontsize=20,color='green',loc='center')
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.plot(
    monthly_order.order_date,
    monthly_order.revenue,
    marker='o',
    linewidth=2,
    color='blue'
)
plt.title('Total revenue per month (2021)',fontsize=20,color='green',loc='center')
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %%
sum_order=all_df.groupby(by='product_name').quantity_x.sum().sort_values(ascending=False).reset_index()
sum_order.head()
# Out:
#       product_name  quantity_x
# 0            Denim         527
# 1          Joggers         334
# 2          Pleated         308
# 3  Casual Slim Fit         306
# 4        Shearling         302

# %%
fig, ax = plt.subplots(nrows=1,ncols=2,figsize=(24,6))
colors = ["#72BCD4", "#72BCD4", "#72BCD4", "#D3D3D3", "#D3D3D3"]
sns.barplot(x='quantity_x',y='product_name',data=sum_order.head(5),palette=colors,ax=ax[0])
ax[0].set_xlabel(None)
ax[0].set_ylabel(None)
ax[0].set_title(
    'Best Performing Product',
    loc='center',
    fontsize=15
)
ax[0].tick_params(axis='y', labelsize=12)

sns.barplot(
    x='quantity_x',
    y='product_name',
    data=sum_order.sort_values(by='quantity_x',ascending=True).head(5),
    palette=colors,ax=ax[1]
)
ax[1].set_xlabel(None)
ax[1].set_ylabel(None)
ax[1].invert_xaxis()
ax[1].yaxis.set_label_position("right")
ax[1].yaxis.tick_right()
ax[1].set_title(
    'Worst Performing Product',
    loc='center',
    fontsize=15
)
ax[1].tick_params(axis='y', labelsize=12)
plt.suptitle(
    "Best and Worst Performing Product by number of sales",
    fontsize=20,
    color='green'
)
plt.show()
# Out:
# <ipython-input-68-cf97da837c41>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='quantity_x',y='product_name',data=sum_order.head(5),palette=colors,ax=ax[0])
# <ipython-input-68-cf97da837c41>:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
by_gender=all_df.groupby(by='gender').customer_id.nunique().reset_index()
by_gender.rename(columns={
    'customer_id': 'customer_count'
},inplace=True
)
colors = ["#72BCD4", "#D3D3D3", "#D3D3D3"]
plt.figure(figsize=(12,6))
sns.barplot(
    x='gender',
    y='customer_count',
    data=by_gender.sort_values(by='customer_count',ascending=False),
    palette=colors
)

plt.title('Number of customer by gender',fontsize=20,loc='center')
plt.ylabel(None)
plt.xlabel(None)
plt.xticks(fontsize=12)
plt.show()
# Out:
# <ipython-input-69-b9f4b074f45c>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
by_age=all_df.groupby(by='age_group').customer_id.nunique().reset_index()
by_age.rename(columns={
    'customer_id': 'customer_count'
},inplace=True
)
by_age['age_group']=pd.Categorical(
    by_age['age_group'],
    categories=['youth','senior','adult'],
    ordered=True
)

plt.figure(figsize=(12,6))
colors = ["#D3D3D3", "#D3D3D3", "#72BCD4"]
sns.barplot(
    x='age_group',
    y='customer_count',
    data=by_age.sort_values(by='age_group',ascending=False),
    palette=colors
)
plt.title('Number of customer by age group',fontsize=20,loc='center')
plt.ylabel(None)
plt.xlabel(None)
plt.xticks(fontsize=12)
plt.show()
# Out:
# <ipython-input-70-0b17823a8adb>:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
by_state=all_df.groupby(by='state').customer_id.nunique().reset_index()
by_state.rename(columns={
    'customer_id': 'customer_count'
},inplace=True
)
plt.figure(figsize=(12,6))
colors = ["#72BCD4", "#72BCD4", "#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]
sns.barplot(
    x='customer_count',
    y='state',
    data=by_state.sort_values(by='customer_count',ascending=False),
    palette=colors
)
plt.title('Number of customer by state',fontsize=20,loc='center')
plt.ylabel(None)
plt.xlabel(None)
plt.yticks(fontsize=12)
plt.show()
# Out:
# <ipython-input-71-4ffb20d4c3cb>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# ##RFM(recency,frequency,monetary)

# %%
rfm_df = all_df.groupby(by="customer_id", as_index=False).agg({
    "order_date": "max", # mengambil tanggal order terakhir
    "order_id": "nunique", # menghitung jumlah order
    "total_price": "sum" # menghitung jumlah revenue yang dihasilkan
})
rfm_df.columns = ["customer_id", "max_order_timestamp", "frequency", "monetary"]

# menghitung kapan terakhir pelanggan melakukan transaksi (hari)
rfm_df["max_order_timestamp"] = rfm_df["max_order_timestamp"].dt.date
recent_date = order_df["order_date"].dt.date.max()
rfm_df["recency"] = rfm_df["max_order_timestamp"].apply(lambda x: (recent_date - x).days)

rfm_df.drop("max_order_timestamp", axis=1, inplace=True)
rfm_df.head()
# Out:
#    customer_id  frequency  monetary  recency
# 0            1          3      1641      203
# 1            7          1      1017      156
# 2           10          1       270      229
# 3           11          1       382      149
# 4           12          1      1551      127

# %%
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(30, 6))

colors = ["#72BCD4", "#72BCD4", "#72BCD4", "#72BCD4", "#72BCD4"]

sns.barplot(y="recency", x="customer_id", data=rfm_df.sort_values(by="recency", ascending=True).head(5), palette=colors, ax=ax[0])
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("By Recency (days)", loc="center", fontsize=18)
ax[0].tick_params(axis ='x', labelsize=15)

sns.barplot(y="frequency", x="customer_id", data=rfm_df.sort_values(by="frequency", ascending=False).head(5), palette=colors, ax=ax[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].set_title("By Frequency", loc="center", fontsize=18)
ax[1].tick_params(axis='x', labelsize=15)

sns.barplot(y="monetary", x="customer_id", data=rfm_df.sort_values(by="monetary", ascending=False).head(5), palette=colors, ax=ax[2])
ax[2].set_ylabel(None)
ax[2].set_xlabel(None)
ax[2].set_title("By Monetary", loc="center", fontsize=18)
ax[2].tick_params(axis='x', labelsize=15)

plt.suptitle("Best Customer Based on RFM Parameters (customer_id)", fontsize=20)
plt.show()
# Out:
# <ipython-input-73-af7d5f90629b>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y="recency", x="customer_id", data=rfm_df.sort_values(by="recency", ascending=True).head(5), palette=colors, ax=ax[0])
# <ipython-input-73-af7d5f90629b>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y="frequency", x="customer_id", data=rfm_df.sort_values(by="frequency", ascending=False).head(5), palette=colors, ax=ax[1])
# <ipython-input-73-af7d5f90629b>:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %% [markdown]
# #Dashboard

# %%
all_df.to_csv('all_data.csv', index=False)
